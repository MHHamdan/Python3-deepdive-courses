# %% [markdown]
# # Packages are modules ... but modules are not packages.. packages can contain subpackaes .. have value ..__path__ .. empty or not present ..
#
# # Packages .. doen't have to be intities in the file system .. file name ... python app.. modules and packages .. don't have to be fiel... hierarchy .. module packages .. pack1.mod1 .. pack1.pack1_1.mod_1 .. __.path__ in the __package__
#
# ##nested packages ... import pack1.pack1_1.module1 ... nested
# ## import pack1
# ### imports pack1.pack1_1
# #### import pack1.packe1_1.moudule1
#
# The sys.modules cache will contain entries for: ..p1, p1.p11, p1.p11.pack
#
# ## Packages can be PEP302 ...
# ## file based module and packages 99% ..of work...
#
# # File based packages .. path created by file system directories and files..
# ## a package is simply a module that contain other module/packages
# ### file system have to ue directoreies for packages ..
# ### directeor name becaomp pakcagee name ...
#
# ### package directory and __init.__.py
#
#
# #### defein a packath create a dircteor whos name will be package name
#
# ### create a__init.__.py insed directo consider a package ... expliciety or implicity
#
#
# '
# app
# / p1
# / _Pinint__py
# m1
# m2
#
#
#
# '
#
#
# i;mport mp1
#
# code for p in __
#
# symob pack1 is adde to our name space refrenci the same object ... a package but ist a module
#
#
#
# but packagh ahs a __Path___ ... is the abs path to pack1  package ... fully qualified path tah represet the package
#
# __file__ property ... is teh fisle contain teh
# in pach is teh patch to th __ininpt_.py
#
#
#
# ## package contaionmdoul as as pakcaetews
#
#
#
# app/
# pack1/
# __init__.py
# m1py
# m2.py
# pack_``/
# init.y
# mq
# mw
#
# # Modules have __file__ and __package__propeties
# file is location .. package is teh code located .. an empty .. packate ha s__path __ locationof the packath ...
#
# Module.__File__ >>/app/modulepy
#
# module.__Path__ >> not set
#
# module.__package__ ' ''
# pcak1.__file__ .. app/pack1/__init.ph
# pack1.__path .. /app/pack1
# pack.PPpackage >> pack1 module.PPflieP .. absolute path ..
# file no set .. when it not a package ... package ...
#
# ../app/pack /apc2.
# packt ot dircotry of package ..
#
# package 1.pack{ap
#
# pack..pcak11.mdoulqa.__file__ .. /app/packq/pack11/modu.py
# nost
# pack.packq.ap
#
# impot pakcq.pack11.modulqa
#
# packq.import and add to sy.module packq_1 impota dn asys sy modul
# modula is imotan and addt o sys.mdoul
#
# mdoules can import other moduel ..
#
# pack1__init__.py
# pack1_1.init.__.ph could import other module and packages }

# %% [markdown]
# # Whay packages
#
#
# api.py ... singl fiel ... with 50 different funcitons
# 1. connect DB
# 2. execute_no_result
# 3. execute_single_row
# 4. execute_multi_row
# 5. normalize_stirng
# 6. convert_str_to_bool
# 7. format_iso_data
# 8. current_time_utc
# 9. authentication
# 10. validate_tocken
# 11. get_permissions
# 12. authorize_endpoint
# 13. User
# 14. User Profile
# 15. Users
# 16. BlogPost
# 17. BlogPosts
# 18. RoutTable
# 19. Configuraton
# 20. JsonEncoder
# 21. UnitTests
# 22. audit_endpoint
# 23. Logger
# 24. Validate_email
# 25. validate_phone
# 26. Validate_name
# ... etc
#
# in one file???????
#
#
#
#
# in moduel =:
#
# # api/
# ## api.py
# ### dbutilities.py
# #### jsonutiltiel.py
# ##### typeconvertingsions.py
# ###### valdiation.pyu
# ###### authnecton aut;herizetion usres bloghjpost loggin utitltn .... imort dbutilte e ...
# might be brocket .. connectiosn queries .. users .. user suers userprofiel ... users.. py ... more .. cetain mdouels .. autheication , autorizetn . security ...
#
# breack ou t suer .. users userproviel .. packah tho users ...
#
#
#
# # api/
# ## -- utitlities/
# ### -- database/ connectiosn, quereis  000 json/ enocder, decoer , --- security / autntication -- authoriztion ..
# ## mdoels/--- users .. user.py ... jusersprofiel ... smaller sub functions .. to uders u.. main func 1 2 3 and 4 .. specifcally ..
#
#
# # decopose problem into a smaller and smaller .....
#
# # a function in a class some boday .. users...
#
# # objects ha buch of staff .. module developers peresopct s..
#
# from modus users' perspfect .. a singlu impot for a fucnt an calss..
#
# singl moduel .. to us brinck to chankd .. 20 functin
#
#
#
#
# # Module Developers Perspexteci
#
#
# - mylib / int sumod sumod2 supack1 ... inint pack2mod2 pac1mod
#
#
# smaller code modu
#
#
#
# # Module users' perpecdfic ... from my liv.su bimp fuc ..
# from myliv.supac.pacmdo impr my class .. or
#
#
#  impor tmylib mli..myfunc9) mylib()
#
#
#
#
#  __init__.py
#
#
#  from myli.sub
#  internal is hidden
#
#
#  # Why packages
#
#  easier to writh
#  test and debut
#  read and undestand
#  document ... lik books are brokdein doei to chapeter , sections , pargrap, etc ..
#
#  bound into one book... how we structrue our code ...
#
#  -- make your code easier tocode and writh .a
